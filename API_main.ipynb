# %% [markdown]
# ### Data Maining HW-1

# %% [markdown]
# #### Task_1

# %%
import requests

# %%
import json

# %%
link = 'https://api.github.com/users'

# %%
response = requests.get(f'{git_link}/{input()}/repos') #Введите User
# Out:
# Zamolotskii

# %%
response #проверяем статус запроса
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"id":246128867,"node_id":"MDEwOlJlcG9zaXRvcnkyNDYxMjg4Njc=","name":"data-mining-2.0","full_name":"Zamolotskii/data-mining-2.0","private":false,"owner":{"login":"Zamolotskii","id":49004481,"node_id":"MDQ6VXNlcjQ5MDA0NDgx","avatar_url":"https://avatars2.githubusercontent.com/u/49004481?v=4","gravatar_id":"","url":"https://api.github.com/users/Zamolotskii","html_url":"https://github.com/Zamolotskii","followers_url":"https://api.github.com/users/Zamolotskii/followers","following_url":"https://api.github.com/users/Zamolotskii/following{/other_user}","gists_url":"https://api.github.com/users/Zamolotskii/gists{/gist_id}","starred_url":"https://api.github.com/users/Zamolotskii/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Zamolotskii/subscriptions","organizations_url":"https://api.github.com/users/Zamolotskii/orgs","repos_url":"https://api.github.com/users/Zamolotskii/repos","events_url":"https://api.github.com/users/Zamolotskii/events{/privacy}","received_even
# ...

# %% [markdown]
# ###### Список репозиториев пользователя:

# %%
if response.ok:
#     Repositories = []
    data = json.loads(response.text)
    for i in data:
        print(i['name'])
#         Repositories.append(i['name'])
# Out:
# data-mining-2.0
# Garbanzo
# GB_data_mining
# MySQL
# Python-DATA-Science

# %% [markdown]
# #### Task_2

# %%
user = input('Please, enter Username or email address:')
password = input('Please, enter your Password:')
# Out:
# Please, enter Username or email address:Zamolotskii
# Please, enter your Password:111stigen

# %%
privat = requests.get(f'{git_link}/{user}/repos', auth=(user, password))

# %%
privat.text
# Out:
# '[{"id":246128867,"node_id":"MDEwOlJlcG9zaXRvcnkyNDYxMjg4Njc=","name":"data-mining-2.0","full_name":"Zamolotskii/data-mining-2.0","private":false,"owner":{"login":"Zamolotskii","id":49004481,"node_id":"MDQ6VXNlcjQ5MDA0NDgx","avatar_url":"https://avatars2.githubusercontent.com/u/49004481?v=4","gravatar_id":"","url":"https://api.github.com/users/Zamolotskii","html_url":"https://github.com/Zamolotskii","followers_url":"https://api.github.com/users/Zamolotskii/followers","following_url":"https://api.github.com/users/Zamolotskii/following{/other_user}","gists_url":"https://api.github.com/users/Zamolotskii/gists{/gist_id}","starred_url":"https://api.github.com/users/Zamolotskii/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Zamolotskii/subscriptions","organizations_url":"https://api.github.com/users/Zamolotskii/orgs","repos_url":"https://api.github.com/users/Zamolotskii/repos","events_url":"https://api.github.com/users/Zamolotskii/events{/privacy}","received_even
# ...
